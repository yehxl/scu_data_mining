# %%
import sys
sys.path.append("..")
import src.grabOne as grabOne
import time
import pandas as pd
from pandas import DataFrame as df
import random

t = pd.DataFrame()
li = ['爱情','动作','短片']
table = []
ct = 0
for i in li:
    path = "D:\\projects\\scu_data_mining\\data\\" + i + ".csv"
    table.append(df(pd.read_csv(path)))
tp = zip(li, table)
for label, item in tp:
    for i in range(0,1):
        index = 'rd' + str(i)
        s = pd.Series(item[index])
        # rd(i) url list
        col = 16+i*3
        url_list = s.str.extract(", '(.*?)'", expand=True).values.tolist()
        info_list = {'genre0':[], 'genre1':[], 'director0':[], 'ReleaseDate': [], 'region0': []}
        for url in url_list:
            ct += 1
            print('数量: ',ct)
            if not url[0] == url[0]:
                continue
            res = grabOne.grabOne(url = url[0])
            time.sleep(1)
            if 'genre0' in res.keys():
                info_list['genre0'].append(res['genre0'])
            else:
                info_list['genre1'].append('unknown')

            if 'genre1' in res.keys():
                info_list['genre1'].append(res['genre1'])
            else:
                info_list['genre1'].append('unknown')
            if 'director0' in res.keys():
                info_list['director0'].append(res['director0'])
            else:
                info_list['director0'].append('director0')
            if 'ReleaseDate' in res.keys():
                info_list['ReleaseDate'].append(res['ReleaseDate'])
            else:
                info_list['ReleaseDate'].append('ReleaseDate')
            if 'director0' in res.keys():
                info_list['region0'].append(res['region0'])
            else:
                info_list['region0'].append('region0')

        pd.DataFrame(info_list).to_csv('D:\\projects\\scu_data_mining\\data\\' + label + '_' + index + '.csv',encoding='utf-8-sig')
# Out:
# 数量:  1
# 200
# 数量:  2
# 200
# 数量:  3
# 200
# 数量:  4
# 200
# 数量:  5
# 200
# 数量:  6
# 200
# 数量:  7
# 200
# 数量:  8
# 200
# 数量:  9
# 200
# 数量:  10
# 200
# 数量:  11
# 200
# 数量:  12
# 200
# 数量:  13
# 200
# 数量:  14
# 200
# list index out of range
# 数量:  15
# 200
# 数量:  16
# 200
# 数量:  17
# 200
# 数量:  18
# 200
# 数量:  19
# 200
# 数量:  20
# 200
# 数量:  21
# 200
# 数量:  22
# 200
# 数量:  23
# 200
# 数量:  24
# 200
# 数量:  25
# 200
# 数量:  26
# 200
# 数量:  27
# 200
# 数量:  28
# 200
# 数量:  29
# 200
# 数量:  30
# 200
# 数量:  31
# 200
# 数量:  32
# 200
# 数量:  33
# 200
# 数量:  34
# 200
# 数量:  35
# 200
# 数量:  36
# 200
# 数量:  37
# 200
# 数量:  38
# 200
# 数量:  39
# 200
# 数量:  40
# 200
# 数量:  41
# 200
# 数量:  42
# 200
# 数量:  43
# 200
# 数量:  44
# 200
# 数量:  45
# 200
# 数量:  46
# 200
# 数量:  47
# 200
# 数量:  48
# 200
# 数量:  49
# 200
# 数量:  50
# 200
# list index out of range
# 数量:  51
# 200
# 数量:  52
# 200
# 数量:  53
# 数量:  54
# 200
# 数量:  55
# 200
# 数量:  56
# 200
# 数量:  57
# 200
# 数量:  58
# 200
# 数量:  59
# 200
# 数量:  60
# 200
# ...

# %%
item
